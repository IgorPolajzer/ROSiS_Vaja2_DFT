# %% [markdown]
# # DFT
#
# ## Primerjava DFT in FFT z generirano sinusuido

# %%
from importlib import reload
import util
from util import *

reload(util)

MAX_FREQS = 5000

T = 1.0
Fs = 500

freq = generate_frequency(1.0, 20, 0.0, T, Fs)

fft_dft(freq, Fs, T, MAX_FREQS)

# %% [markdown]
# ## Test posnetkov
# ### "a"

# %%
y_a, Fsa = util.read_signal_from_mp3("/home/igor/Desktop/MAG/1_LETNIK/2_SEMESTER/RACUNALNISKA_OBDELAVA_SIGNALOV_IN_SLIK/Vaja_2/recordings/a_medium_pitch.mp3")
T = len(y_a) / Fsa
fft_dft(y_a, Fsa, T, MAX_FREQS)

# %% [markdown]
# ### "i"

# %%
y_i, Fsi = util.read_signal_from_mp3("/home/igor/Desktop/MAG/1_LETNIK/2_SEMESTER/RACUNALNISKA_OBDELAVA_SIGNALOV_IN_SLIK/Vaja_2/recordings/i_medium_pitch.mp3")
T = len(y_i) / Fsi
fft_dft(y_i, Fsi, T, MAX_FREQS)

# %% [markdown]
# ### "o"

# %%
y_o, Fso = util.read_signal_from_mp3("/home/igor/Desktop/MAG/1_LETNIK/2_SEMESTER/RACUNALNISKA_OBDELAVA_SIGNALOV_IN_SLIK/Vaja_2/recordings/o_medium_pitch.mp3")
T = len(y_o) / Fso
fft_dft(y_o, Fso, T, MAX_FREQS)

# %% [markdown]
# # Vprašanja
#
# **1. Ali lahko frekvenčno sliko signala nedvoumno določimo preko skalarnega produkta med posnetim signalom in izbrano realno sinusoido? Zakaj?**

# %%
freq = generate_frequency(1.0, 20, 0.0, T, Fs)
real_freq = generate_frequency(1.0, 200, 0.0, T, Fs)
y_dft = real_sin_dft(freq, Fs, T, real_freq, MAX_FREQS)
plot_analasys(y_dft, Fs, T, 'real DFT')

# %% [markdown]
# O: Ne. Če ima signal enako frekvenco kot testna sinusoida in fazni zamik 90°, bo skalarni produkt približno 0, kar napačno nakazuje da te frekvence v signalu ni, čeprav je prisotna. Frekvenčna analiza z realnimi sinusuidami postane preveč odvisna od faze, zaradi česa je neuporabna.

# %% [markdown]
# **2. Ali lahko frekvenčno sliko signala nedvoumno določimo preko skalarnega produkta med posnetim signalom in izbrano kompleksno sinusoido? Kako na to vpliva dolžina opazovanega intervala signala? Zakaj?**
#
# O: Da, saj kompleksna sinusuida hkrati vsebuje sin in cos, kar naredi analizo neodvisno od faze. Primer je demonstriran na začetku notebooka, ter na primerih "a", "i", "o". Dolžina signala vpliva na frekvenčno ločljivost v frekvenčni analizi na naslednji način: če je signal krajši bo ločljivost slabša, če pa je daljši pa bo ločljivost boljša.

# %% [markdown]
# **3. Katere vse frekvence so prisotne v izgovorjavi samoglasnikov »a«, »i« in »o« (osredotočite se na frekvence, ki predstavljajo vsaj 1 % celotne energije signal_a)?**
#
# O: Glede na zgoraj prikazane frekvenčne analize samoglasinkov "a", "i", in "o", lahko razberemo naslednje:
# - "a" -> 125, 240, 370, 490, 625, 725, 850, 900, 1100, 1200
# - "i" -> 125, 240, 370, 490
# - "o" -> 125, 240, 370, 490, 625, 725, 850
#
# Frekvence posameznih črk med sabo vsebujejo enake frekvence, le da ne vsebujejo vse vseh.

# %% [markdown]
# **4. Kako so frekvence, ki so prisotne v izgovorjavi samoglasnikov »a«, »i« in »o« odvisne od višine tona izgovorjave?**
#
# O: Z višanjem tona izgovorjave se vse frekvence premaknejo višje.
#
# **5. Kako se z višino tona izgovorjave spremeni pojav višjih harmonikov v frekvenčni sliki?**
#
# O: Višji toni imajo vidnih manjše število višjih harmonikov kot nižji toni.

# %%
# Nizki ton i.
y_a_low, Fs_a_low = util.read_signal_from_mp3("/home/igor/Desktop/MAG/1_LETNIK/2_SEMESTER/RACUNALNISKA_OBDELAVA_SIGNALOV_IN_SLIK/Vaja_2/recordings/i_medium_pitch.mp3")
y_dft_a_low = dft(y_a_low, Fs_a_low, T, MAX_FREQS)
plot_analasys(y_dft_a_low, Fs_a_low, T, 'Nizki ton i DFT')

# Visoki ton i.
y_a_high, Fs_a_high = util.read_signal_from_mp3("/home/igor/Desktop/MAG/1_LETNIK/2_SEMESTER/RACUNALNISKA_OBDELAVA_SIGNALOV_IN_SLIK/Vaja_2/recordings/i_high_pitch.mp3")
y_dft_a_high = dft(y_a_high, Fs_a_high, T, MAX_FREQS)
plot_analasys(y_dft_a_high, Fs_a_high, T, 'Visoki ton i DFT')

# Nizki ton a.
y_a_low, Fs_a_low = util.read_signal_from_mp3("/home/igor/Desktop/MAG/1_LETNIK/2_SEMESTER/RACUNALNISKA_OBDELAVA_SIGNALOV_IN_SLIK/Vaja_2/recordings/a_medium_pitch.mp3")
y_dft_a_low = dft(y_a_low, Fs_a_low, T, MAX_FREQS)
plot_analasys(y_dft_a_low, Fs_a_low, T, 'Nizki ton a DFT')

# Visoki ton a.
y_a_high, Fs_a_high = util.read_signal_from_mp3("/home/igor/Desktop/MAG/1_LETNIK/2_SEMESTER/RACUNALNISKA_OBDELAVA_SIGNALOV_IN_SLIK/Vaja_2/recordings/a_high_pitch.mp3")
y_dft_a_high = dft(y_a_high, Fs_a_high, T, MAX_FREQS)
plot_analasys(y_dft_a_high, Fs_a_high, T, 'Visoki ton a DFT')

# Nizki ton o.
y_a_low, Fs_a_low = util.read_signal_from_mp3("/home/igor/Desktop/MAG/1_LETNIK/2_SEMESTER/RACUNALNISKA_OBDELAVA_SIGNALOV_IN_SLIK/Vaja_2/recordings/o_medium_pitch.mp3")
y_dft_a_low = dft(y_a_low, Fs_a_low, T, MAX_FREQS)
plot_analasys(y_dft_a_low, Fs_a_low, T, 'Nizki ton o DFT')

# Visoki ton o.
y_a_high, Fs_a_high = util.read_signal_from_mp3("/home/igor/Desktop/MAG/1_LETNIK/2_SEMESTER/RACUNALNISKA_OBDELAVA_SIGNALOV_IN_SLIK/Vaja_2/recordings/o_high_pitch.mp3")
y_dft_a_high = dft(y_a_high, Fs_a_high, T, MAX_FREQS)
plot_analasys(y_dft_a_high, Fs_a_high, T, 'Visoki ton o DFT')
