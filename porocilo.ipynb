# %% [markdown]
# # DFT
#
# ## Primerjava DFT in FFT z generirano sinusuido

# %%
import numpy as np
from importlib import reload
import util
from util import generate_frequency, plot_dft_and_fft

reload(util)


T = 1.0
Fs = 500

freq = generate_frequency(1.0, 20, 0.0, T, Fs)

y_dft = util.dft(freq, Fs, T)
y_fft = np.fft.fft(freq)

plot_dft_and_fft(y_fft, y_dft, T, Fs)
